# %%
from pyarc.data_structures import ClassAssocationRule
from pyids.data_structures import IDSRule
import numpy as np

# %%
def print_cars(ids_cars):
    cars = ids_cars
    is_ids = False
    if type(ids_cars[0]) == IDSRule:
        is_ids = [ r.calc_f1() for r in ids_cars ]
        cars = [ r.car for r in ids_cars ]
    latex = []
    for idx, car in enumerate(cars):
        if is_ids:
            latex.append(car_to_latex(car, is_ids=is_ids[idx]))
        else:
            latex.append(car_to_latex(car))
        
    return "\n\n".join(latex)
        
def car_to_latex(car, is_ids=False):
    trans = {
        "-":  r"\-",
        "_":  r"\_",
        "]":  r"\]",
        "\\": r"\\",
        "^":  r"\^",
        "$":  r"\$",
        "*":  r"\*",
        ".":  r"\."
    }
    latex = []
    
    latex.append("If")
    
    for idx, predicate in enumerate(car.antecedent):
       
        name, interval = predicate
        name = name.translate(str.maketrans(trans))
        
        interval_string = interval.translate(str.maketrans(trans))
        
        if idx != 0:
            latex.append("and")
        latex.append(
            f"\\textcolor{{blue}}{{{name}}}=\\textcolor{{gray}}{{{interval_string}}}"
        )

        
    class_name, class_value = car.consequent
    
    latex.append("then")
    latex.append(
        f"\\textcolor{{red}}{{{class_name}}}=\\textcolor{{gray}}{{{class_value}}}"
    )
    
    if is_ids:
        latex.append(
            f"$\mid$ f1-score: \\textit{{{round(is_ids, 2)}}}"
        )
    
    return " ".join(latex)

# %% [markdown]
# # IDS Demonstration

# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd
import pyarc
from pyids import IDS
from pyids.data_structures import (
    mine_CARs,
    RSOptimizer,
    IDSObjectiveFunction,
    ObjectiveFunctionParameters,
    IDSRuleSet,
    IDSRule,
    SLSOptimizer
)
from pyids.rule_mining import RuleMiner
from pyarc.qcba.data_structures import QuantitativeDataFrame

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Loading the test and train data

# %%
data = pd.read_csv("../data/titanic.csv").sample(frac=1).reset_index(drop=True)


data_train, data_test = train_test_split(data, test_size=0.8)

# %%
data.head()
# Out:
#   Passenger_Cat Age_Cat  Gender  Died
# 0          crew   adult    male     1
# 1          crew   adult    male     1
# 2     2nd_class   adult    male     1
# 3     3rd_class   child  female     1
# 4     1st_class   adult  female     0

# %%
rules = mine_CARs(data_train, 40)
# Out:
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=4
# Rule count: 52, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 2
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 3
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 4
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 5
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 6
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 7
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 8
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 9
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 10
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 11
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=4
# Rule count: 74, Iteration: 12
# All options exhausted

# %%
quant_dataframe_train = QuantitativeDataFrame(data_train)
quant_dataframe_test = QuantitativeDataFrame(data_test)
# Out:
# D:\programy\Anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_train.sample(len(data_train)).head(20)
# Out:
#      Passenger_Cat Age_Cat  Gender Died
# 286           crew   adult    male    0
# 1390     2nd_class   adult    male    1
# 1091          crew   adult  female    0
# 567           crew   adult    male    1
# 1018     1st_class   adult    male    0
# 636      3rd_class   adult    male    0
# 564      2nd_class   adult    male    0
# 593      1st_class   adult    male    1
# 547           crew   adult  female    0
# 179      2nd_class   adult  female    0
# 821           crew   adult  female    0
# 733      2nd_class   adult    male    1
# 839      3rd_class   adult    male    1
# 1240     1st_class   adult    male    1
# 1420          crew   adult    male    1
# 1621     3rd_class   adult  female    0
# 1169     3rd_class   adult    male    1
# 1015          crew   adult    male    1
# 1104     2nd_class   adult  female    0
# 1087     1st_class   adult  female    0

# %%
params = ObjectiveFunctionParameters()
params.params["all_rules"] = IDSRuleSet.from_cba_rules(rules)
params.params["quant_dataframe"] = quant_dataframe_train
params.params["len_all_rules"] = len(rules)
params.params["lambda_array"] = [1] + 6 * [0]
#params.params["lambda_array"] = [0, 0, 1, 0, 0, 0, 0]

obj_func = IDSObjectiveFunction(params)
# Out:
# cover cache prepared
# overlap cache prepared

# %%
len(rules)
# Out:
# 40

# %%
result_dict = dict(
    len_r=[],
    f0=[]
)

for _ in range(10000):
    ids_ruleset = IDSRuleSet.from_cba_rules(rules)
    rs_opt = RSOptimizer(rules)

    result = rs_opt.optimize()
    
    result_dict["len_r"].append(len(result))
    
    f0 = obj_func.f0(IDSRuleSet.from_cba_rules(result))
    result_dict["f0"].append(f0)

# %%
result_df_dict = dict(sample_size=[], mean_f0=[])

for i in range(0, 5):
    sample_size = 10**i
    
    sample = np.random.choice(result_dict["f0"], sample_size)
    
    sample_mean = np.mean(sample)
    
    result_df_dict["sample_size"].append(sample_size)
    result_df_dict["mean_f0"].append(sample_mean)

    
result_df = pd.DataFrame(result_df_dict)
> 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03165712073824506
# INFO - 0.03165712073824506 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031643277708370124
# INFO - 0.031643277708370124 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031632430540836844
# INFO - 0.031632430540836844 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031620719507454105
# INFO - 0.031620719507454105 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031612961409745656
# INFO - 0.031612961409745656 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03160554994804241
# INFO - 0.03160554994804241 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.0315955835583286
# INFO - 0.0315955835583286 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031585930161334194
# INFO - 0.031585930161334194 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03157162559706373
# INFO - 0.03157162559706373 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03156436989641518
# INFO - 0.03156436989641518 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03155460515057281
# INFO - 0.03155460515057281 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03154464671601936
# INFO - 0.03154464671601936 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031538449679129374
# INFO - 0.031538449679129374 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03152544435476516
# INFO - 0.03152544435476516 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031527380520485586
# INFO - 0.031527380520485586 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03151577669147122
# INFO - 0.03151577669147122 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031511765241272104
# INFO - 0.031511765241272104 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03150147474054169
# INFO - 0.03150147474054169 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03149251819364397
# INFO - 0.03149251819364397 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.0314787283690396
# INFO - 0.0314787283690396 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03146970945923038
# INFO - 0.03146970945923038 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03146035739091322
# INFO - 0.03146035739091322 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031454314816792193
# INFO - 0.031454314816792193 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031447351191798145
# INFO - 0.031447351191798145 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031441582532352484
# INFO - 0.031441582532352484 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03143213554609528
# INFO - 0.03143213554609528 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03142054465290274
# INFO - 0.03142054465290274 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031408550978198814
# INFO - 0.031408550978198814 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03139923734680695
# INFO - 0.03139923734680695 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031395750229552766
# INFO - 0.031395750229552766 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031383371992483075
# INFO - 0.031383371992483075 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03137953018880384
# INFO - 0.03137953018880384 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.031372221215271806
# INFO - 0.031372221215271806 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03136057757559079
# INFO - 0.03136057757559079 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.0313480387207298
# INFO - 0.0313480387207298 > 0.01375 => omega estimation continues
# INFO - stardard error of omega estimate: 0.03133950130860661
# INFO - 0.03133950130860661 > 0.01375 => omega estimation continues
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-804a6bd01b1f> in <module>
#       1 sls_opt = SLSOptimizer(obj_func, params)
#       2
# ----> 3 sls_opt.optimize()
#
# D:\programy\Anaconda\lib\site-packages\pyids\data_structures\ids_optimizer.py in optimize(self)
#     167
#     168     def optimize(self):
# --> 169         solution1 = self.optimize_delta(1/3, 1/3)
#     170         solution2 = self.optimize_delta(1/3, -1.0)
#     171
#
# D:\programy\Anaconda\lib\site-packages\pyids\data_structures\ids_optimizer.py in optimize_delta(self, delta, delta_prime)
#     115                 self.debug_message("INFO - Estimating omega for rule: {}".format(rule))
#     116
# --> 117                 omega_est = self.estimate_omega(rule, soln_set, 1.0/(n*n) * OPT, delta)
#     118                 omega_estimates.append(omega_est)
#     119
#
# D:\programy\Anaconda\lib\site-packages\pyids\data_structures\ids_optimizer.py in estimate_omega(self, rule, solution_set, error_threshold, delta)
#      74                 exp_exclude_func_vals.append(func_val)
#      75
# ---> 76             variance_exp_include = np.var(exp_include_func_vals)
#      77             variance_exp_exclude = np.var(exp_exclude_func_vals)
#      78             standard_error = math.sqrt(variance_exp_include/len(exp_include_func_vals) + variance_exp_exclude/len(exp_exclude_func_vals))
#
# D:\programy\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in var(a, axis, dtype, out, ddof, keepdims)
#    3365
#    3366     return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# -> 3367                          **kwargs)
#    3368
#    3369
#
# D:\programy\Anaconda\lib\site-packages\numpy\core\_methods.py in _var(a, axis, dtype, out, ddof, keepdims)
#     115     # Note that x may not be inexact and that we need it to be an array,
#     116     # not a scalar.
# --> 117     x = asanyarray(arr - arrmean)
#     118     if issubclass(arr.dtype.type, nt.complexfloating):
#     119         x = um.multiply(x, um.conjugate(x), out=x).real
#
# KeyboardInterrupt:

# %%
rule0 = IDSRule(rules[0])

def get_random_set():
    return sls_opt.sample_random_set(set(), sls_opt.delta)

def calculate_omega(rule):
    ids_ruleset = IDSRuleSet(get_random_set())
    ids_ruleset.ruleset = ids_ruleset.ruleset | {rule}
    
    f = obj_func.evaluate(ids_ruleset)
    
    return f


def calculate_omega_no_rule(rule):
    ids_ruleset = IDSRuleSet(get_random_set())
    ids_ruleset.ruleset = ids_ruleset.ruleset - {rule}
    
    f = obj_func.evaluate(ids_ruleset)
    
    
    return f


def estimate(rule):
    est_array_inc = []
    est_array_exc = []
    
    for _ in range(10000):
        est_array_inc.append(calculate_omega(rule))
        est_array_exc.append(calculate_omega_no_rule(rule))
        
    return est_array_inc, est_array_exc

        
est_inc, est_exc = estimate(rule0)

# %%
std_err_result = dict(sample_size=[], stderr=[])

for i in range(0, 5):
    sample_size = 10**i
    
    current_est_exc = np.random.choice(est_exc, sample_size)
    current_est_inc = np.random.choice(est_inc, sample_size)
    
    current_sqrt = np.sqrt(np.var(current_est_exc) / sample_size + np.var(current_est_inc) / sample_size)
    
    result_df_dict["sample_size"].append(sample_size)
    result_df_dict["mean_f0"].append(current_sqrt)

    
result_df = pd.DataFrame(result_df_dict)
result_df.columns = ["Velikost vzorku", "Směrodatná chyba odhadu $\omega$"]

print(result_df.to_latex())

np.sqrt(np.var(est_inc) / len(est_inc) + np.var(est_exc) / len(est_exc))
# Out:
# 0.0422995099617005

# %% [markdown]
# ## Evaluating the IDS model

# %%
print("Accuracy on train data: ", ids.score(quant_dataframe_train))
print("Accuracy on test data: ", ids.score(quant_dataframe_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-172-fe632d029096> in <module>
# ----> 1 print("Accuracy on train data: ", ids.score(quant_dataframe_train))
#       2 print("Accuracy on test data: ", ids.score(quant_dataframe_test))
#
# NameError: name 'ids' is not defined

# %%
print("AUC on train data: ", ids.score_auc(quant_dataframe_train, confidence_based=False))
print("AUC on test data: ", ids.score_auc(quant_dataframe_test, confidence_based=False))
# Out:
# AUC on train data:  0.5
# AUC on test data:  0.5

# %%
print("AUC on train data: ", ids.score_auc(quant_dataframe_train, confidence_based=True))
print("AUC on test data: ", ids.score_auc(quant_dataframe_test, confidence_based=True))
# Out:
# AUC on train data:  0.4980092051431911
# AUC on test data:  0.5066550912756749

# %%
ids.score_interpretable_metrics(quant_dataframe_train)
# Out:
# {'fraction_overlap': 0.27746212121212127,
#  'fraction_classes': 1.0,
#  'fraction_uncovered': 0.0,
#  'average_rule_width': 1.8571428571428572,
#  'ruleset_length': 7}

# %%
ids.score_interpretable_metrics(quant_dataframe_test)
# Out:
# {'fraction_overlap': 0.27709621818919195,
#  'fraction_classes': 1.0,
#  'fraction_uncovered': 0.0,
#  'average_rule_width': 1.8571428571428572,
#  'ruleset_length': 7}
